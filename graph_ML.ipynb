# %%
import networkx as nx

# %%
grph = nx.read_graphml('/Users/shamanthk/Documents/Research/IS-modeling-connectomes/repeated_10_scale_500/100206_repeated10_scale500.graphml')
A = nx.adjacency_matrix(grph)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow(A.toarray(), cmap='YlGnBu')
plt.colorbar()
plt.title('100206 Connectome')
plt.show()

# %%
grph = nx.read_graphml('/Users/shamanthk/Documents/Research/IS-modeling-connectomes/Averaged_1015.graphml')

A = nx.adjacency_matrix(grph)

plt.imshow(A.toarray(), cmap='YlGnBu')
plt.colorbar()
plt.title('Averaged Connectome')
plt.show()
