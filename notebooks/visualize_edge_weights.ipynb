# %%
import sys
sys.path.append("/Users/shamanthk/Documents/Research/IS-modeling-connectomes")
from utils import *

# %%
# %matplotlib widget
sub_100206_graph, partition, unique_clusters = visualize_network('/Users/shamanthk/Documents/Research/IS-modeling-connectomes/repeated_10_scale_500/100206_repeated10_scale500.graphml', sub_id='100206', clustering=True, use_3d=True, plot=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
get_edge_weight_dist(sub_100206_graph, partition, unique_clusters)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
get_edge_weight_dist(sub_100206_graph, partition, unique_clusters, subplots=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fget_clusters(partition)
# Out:
# Cluster 0:
# ...
