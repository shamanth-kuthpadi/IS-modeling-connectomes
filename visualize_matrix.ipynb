# %%
from utils import *

# %%
visualize_connectome('/Users/shamanthk/Documents/Research/IS-modeling-connectomes/Averaged_1015.graphml', sub_id='average')

# %%
visualize_connectome('/Users/shamanthk/Documents/Research/IS-modeling-connectomes/repeated_10_scale_500/100206_repeated10_scale500.graphml', sub_id='100206')
