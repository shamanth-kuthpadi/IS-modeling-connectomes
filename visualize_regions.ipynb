# %%
from Connectome import *

# %%
# %matplotlib widget

# %%
connectome = Connectome('data/Averaged_1015.graphml', label='')

connectome.read_net(use_3d=True)
connectome.plot_net(use_3d=True, color_rgn='dn_name')
# Out:
# ['Brain-Stem', 'Left-Accumbens-area', 'Left-Amygdala', 'Left-Caudate', 'Left-Hippocampus', 'Left-Pallidum', 'Left-Putamen', 'Left-Thalamus-Proper', 'Right-Accumbens-area', 'Right-Amygdala', 'Right-Caudate', 'Right-Hippocampus', 'Right-Pallidum', 'Right-Putamen', 'Right-Thalamus-Proper', 'lh.bankssts', 'lh.caudalanteriorcingulate', 'lh.caudalmiddlefrontal', 'lh.cuneus', 'lh.entorhinal', 'lh.frontalpole', 'lh.fusiform', 'lh.inferiorparietal', 'lh.inferiortemporal', 'lh.insula', 'lh.isthmuscingulate', 'lh.lateraloccipital', 'lh.lateralorbitofrontal', 'lh.lingual', 'lh.medialorbitofrontal', 'lh.middletemporal', 'lh.paracentral', 'lh.parahippocampal', 'lh.parsopercularis', 'lh.parsorbitalis', 'lh.parstriangularis', 'lh.pericalcarine', 'lh.postcentral', 'lh.posteriorcingulate', 'lh.precentral', 'lh.precuneus', 'lh.rostralanteriorcingulate', 'lh.rostralmiddlefrontal', 'lh.superiorfrontal', 'lh.superiorparietal', 'lh.superiortemporal', 'lh.supramarginal', 'lh.temporalpole', 'lh.transversetem
# ...
